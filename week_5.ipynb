# %% [markdown]
# <a href="https://colab.research.google.com/github/seanmcconney10-rgb/pythonlearnin/blob/main/week_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = int(input("Enter age:"))
hour = int(input("Enter movie hour (0-23):"))
if age >= 65 and hour <17:
  price = 6.00
else:
    price = 10.00
    print(f"Your ticket price is $ {price:.2f}")
# Out:
# Enter age:19
# Enter movie hour (0-23):17
# Your ticket price is $ 10.00
