# %% [markdown]
# <a href="https://colab.research.google.com/github/seanmcconney10-rgb/pythonlearnin/blob/week-2/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# this is my first python comment

# this is my second python comment

# %%
print("the total number of minutes is", 120+45 )
# Out:
# the total number of minutes is 165

# %%
print("it has been", 2026-1947,"years since the first computer bug was found")
# Out:
# it has been 79 years since the first computer bug was found

# %%
print("the total cost of buying 7 python books that cost 35$ is",7*35, )
# Out:
# the total cost of buying 7 python books that cost 35$ is 245
