# %% [markdown]
# <a href="https://colab.research.google.com/github/seanmcconney10-rgb/pythonlearnin/blob/main/week_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("* " * 8)


jordan = "Jordan"
print(f"name:{jordan}.",end=' ')
print(f"Age:{22}.",end=' ')
print(f"goal:{'Learn python'}.",end=' ')



print("* " * 8)
print("* " * 8)


ada_lovelace = "Ada Lovelace"
print(f"name:{ada_lovelace}.",end=' ')
print(f"Age:{36}.",end=' ')
print(f"goal:{'invent computing'}.",end=' ')

print("* " * 8)
print("* " * 8)

Sherlock = "Sherlock"
print(f"name:{Sherlock}.",end=' ')
print(f"Age:{40}.",end=' ')
print(f"goal:{'solve crimes'}.",end=' ')



print("* " * 8)
print("* " * 8)
# Out:
# * * * * * * * *
# name:Jordan. Age:22. goal:Learn python. * * * * * * * *
# * * * * * * * *
# name:Ada Lovelace. Age:36. goal:invent computing. * * * * * * * *
# * * * * * * * *
# name:Sherlock. Age:40. goal:solve crimes. * * * * * * * *
# * * * * * * * *
