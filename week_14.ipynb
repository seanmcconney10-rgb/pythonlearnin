# %% [markdown]
# <a href="https://colab.research.google.com/github/seanmcconney10-rgb/pythonlearnin/blob/main/week_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class book:
  def __init__(self,title,author):
    self.title=title
    self.author=author
    self.status="available"

  def checkout(self):
    if self.status == "available" :
      print(f"Checking out '{self.title}'...")
      self.status="checked out"
    else:
      print(f"{self.title} is already checked out.")

  def __str__(self):
    return f"{self.title} by {self.author} - {self.status}"

book1=book("Think python", "Allen Downey")
book2 = book("The Hobbit", "J.R.R. Tolkien")

print("--- Library Status ---")
print(book1)
print(book2)

book1.checkout()

print("\n--- Updated Status ---")
print(book1)
print(book2)
# Out:
# --- Library Status ---
# Think python by Allen Downey - available
# The Hobbit by J.R.R. Tolkien - available
# Checking out 'Think python'...
#
# --- Updated Status ---
# Think python by Allen Downey - checked out
# The Hobbit by J.R.R. Tolkien - available
