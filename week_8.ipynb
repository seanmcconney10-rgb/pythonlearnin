# %% [markdown]
# <a href="https://colab.research.google.com/github/seanmcconney10-rgb/pythonlearnin/blob/main/week_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_palindrome(text):
  text = str(text)
  return text == text[::-1]

print(is_palindrome("RACECAR")) #True
print(is_palindrome("racecar")) #True
# Out:
# True
# True
