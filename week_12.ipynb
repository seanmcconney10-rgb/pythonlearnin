# %% [markdown]
# <a href="https://colab.research.google.com/github/seanmcconney10-rgb/pythonlearnin/blob/main/week_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
length = float(input("Enter length: "))
width = float(input("Enter width: "))
area = length * width
perimeter = 2*(length + width)

print("\n--- Results ---")
print(f"The area is: {area}")
print(f"the perimeter is: {perimeter}")
# Out:
# Enter length: 10
# Enter width: 5
#
# --- Results ---
# The area is: 50.0
# the perimeter is: 30.0
